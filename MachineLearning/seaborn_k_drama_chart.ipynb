# %% [markdown]
# ## K-Drama Chart
# Practice for real-world application

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# #### Step 1: Attach a dataset to the notebook

# %% [markdown]
# #### Step 2: Specify the filepath

# %%
# Fill in the line below: Specify the path of the CSV file to read
my_filepath = 'kdrama.csv'
# Path of the file to read
my_data = pd.read_csv(my_filepath, index_col='Name', parse_dates=True) # Read the file into a variable spotify_data
my_data2 = my_data[['Year of release', 'Original Network', 'Rating', 'Genre', 'Cast']]
#my_data.info() # 15 columns: Name, Aired Date, Year of release, Original Network, Aired On, Content Rating, Rating, Genre, Screenwriter, Cast, Rank
#my_data.shape # (250, 16) meaning 250 rows and 16 columns
#my_data.describe()

my_data2.head() # NaN = Not a Number
# Out:
#                      Year of release Original Network  Rating  \
# Name
# Move to Heaven                  2021          Netflix     9.2
# Flower of Evil                  2020              tvN     9.1
# Hospital Playlist               2020   Netflix,  tvN      9.1
# Hospital Playlist 2             2021   Netflix,  tvN      9.1
# My Mister                       2018              tvN     9.1
#
#                                                        Genre  \
# Name
# Move to Heaven                        Life,  Drama,  Family
# Flower of Evil       Thriller,  Romance,  Crime,  Melodrama
# Hospital Playlist     Friendship,  Romance,  Life,  Medical
# Hospital Playlist 2   Friendship,  Romance,  Life,  Medical
# My Mister             Psychological,  Life,  Drama,  Family
#
#                                                                   Cast
# Name
# Move to Heaven       Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...
# ...

# %% [markdown]
# ## Bar Chart

# %%
# Set the width and height of the figure
plt.figure(figsize=(16, 66))

# Add title
plt.title("K-drama List by rating")

# Bar chart showing k-drama list by rating
sns.barplot(x=my_data['Rating'], y=my_data.index) # sns refers to the seaborn library

# Add label for vertical axis
plt.xlabel("")
# Out:
# Text(0.5, 0, '')
